# %%
#Importing required libraries
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('diabetic_retinopathy.csv')
df
# Out:
#       attribute0  attribute1  attribute2  attribute3  attribute4  attribute5  \
# 0              1           1          22          22          22          19
# 1              1           1          24          24          22          18
# 2              1           1          62          60          59          54
# 3              1           1          55          53          53          50
# 4              1           1          44          44          44          41
# ...          ...         ...         ...         ...         ...         ...
# 1146           1           1          34          34          34          33
# 1147           1           1          49          49          49          49
# 1148           1           0          49          48          48          45
# 1149           1           1          39          36          29          23
# 1150           1           1           7           7           7           7
#
#       attribute6  attribute7  attribute8  attribute9  attribute10  \
# 0             18          14   49.895756   17.775994     5.270920
# 1             16          13   57.709936   23.799994     3.325423
# 2             47          33   55.831441   27.993933    12.687485
# 3             43          31   40.467228   18.445954     9.118901
# 4             39          27   18.026254    8.570709     0.410381
# ...          ...         ...         ...         ...          ...
# 1146          31          24    6.071765    0.937472     0.031145
# 1147          45          37   63.197145   27.377668     8.067688
# 1148          43          33   30.461898   13.966980     1.763305
# 1149          13           7   40.525739   12.604947     4.740919
# 1150           7           5   69.423565    7.031843     1.750548
#
#       attribute11  attribute12  attribute13  attribute14  attribute15  \
# 0        0.771761     0.018632     0.006864     0.003923     0.003923
# 1        0.234185     0.003903     0.003903     0.003903     0.003903
# 2        4.852282     1.393889     0.373252     0.041817     0.007744
# 3        3.079428     0.840261     0.272434     0.007653     0.001531
# 4        0.000000     0.000000     0.000000     0.000000     0.000000
# ...           ...          ...          ...          ...          ...
# 1146     0.003115     0.000000     0.000000     0.000000     0.000000
# 1147     0.979548     0.001552     0.000000     0.000000     0.000000
# 1148     0.137858     0.011221     0.000000     0.000000     0.000000
# 1149     1.077570     0.563518     0.326860     0.239568     0.174584
# 1150     0.046597     0.021180     0.008472     0.000000     0.000000
#
#       attribute16  attribute17  attribute18  attributeClass
# 0        0.486903     0.100025            1               0
# 1        0.520908     0.144414            0               0
# 2        0.530904     0.128548            0               1
# 3        0.483284     0.114790            0               0
# 4        0.475935     0.123572            0               1
# ...           ...          ...          ...             ...
# 1146     0.537470     0.116795            0               0
# 1147     0.516733     0.124190            0               0
# 1148     0.560632     0.129843            0               0
# 1149     0.485972     0.106690            1               1
# 1150     0.556192     0.088957            0               0
#
# [1151 rows x 20 columns]

# %%
df.dtypes
# Out:
# attribute0          int64
# attribute1          int64
# attribute2          int64
# attribute3          int64
# attribute4          int64
# attribute5          int64
# attribute6          int64
# attribute7          int64
# attribute8        float64
# attribute9        float64
# attribute10       float64
# attribute11       float64
# attribute12       float64
# attribute13       float64
# attribute14       float64
# attribute15       float64
# attribute16       float64
# attribute17       float64
# attribute18         int64
# attributeClass      int64
# dtype: object

# %%
df.isna().sum()
# Out:
# attribute0        0
# attribute1        0
# attribute2        0
# attribute3        0
# attribute4        0
# attribute5        0
# attribute6        0
# attribute7        0
# attribute8        0
# attribute9        0
# attribute10       0
# attribute11       0
# attribute12       0
# attribute13       0
# attribute14       0
# attribute15       0
# attribute16       0
# attribute17       0
# attribute18       0
# attributeClass    0
# dtype: int64

# %%
df.dropna()
# Out:
#       attribute0  attribute1  attribute2  attribute3  attribute4  attribute5  \
# 0              1           1          22          22          22          19
# 1              1           1          24          24          22          18
# 2              1           1          62          60          59          54
# 3              1           1          55          53          53          50
# 4              1           1          44          44          44          41
# ...          ...         ...         ...         ...         ...         ...
# 1146           1           1          34          34          34          33
# 1147           1           1          49          49          49          49
# 1148           1           0          49          48          48          45
# 1149           1           1          39          36          29          23
# 1150           1           1           7           7           7           7
#
#       attribute6  attribute7  attribute8  attribute9  attribute10  \
# 0             18          14   49.895756   17.775994     5.270920
# 1             16          13   57.709936   23.799994     3.325423
# 2             47          33   55.831441   27.993933    12.687485
# 3             43          31   40.467228   18.445954     9.118901
# 4             39          27   18.026254    8.570709     0.410381
# ...          ...         ...         ...         ...          ...
# 1146          31          24    6.071765    0.937472     0.031145
# 1147          45          37   63.197145   27.377668     8.067688
# 1148          43          33   30.461898   13.966980     1.763305
# 1149          13           7   40.525739   12.604947     4.740919
# 1150           7           5   69.423565    7.031843     1.750548
#
#       attribute11  attribute12  attribute13  attribute14  attribute15  \
# 0        0.771761     0.018632     0.006864     0.003923     0.003923
# 1        0.234185     0.003903     0.003903     0.003903     0.003903
# 2        4.852282     1.393889     0.373252     0.041817     0.007744
# 3        3.079428     0.840261     0.272434     0.007653     0.001531
# 4        0.000000     0.000000     0.000000     0.000000     0.000000
# ...           ...          ...          ...          ...          ...
# 1146     0.003115     0.000000     0.000000     0.000000     0.000000
# 1147     0.979548     0.001552     0.000000     0.000000     0.000000
# 1148     0.137858     0.011221     0.000000     0.000000     0.000000
# 1149     1.077570     0.563518     0.326860     0.239568     0.174584
# 1150     0.046597     0.021180     0.008472     0.000000     0.000000
#
#       attribute16  attribute17  attribute18  attributeClass
# 0        0.486903     0.100025            1               0
# 1        0.520908     0.144414            0               0
# 2        0.530904     0.128548            0               1
# 3        0.483284     0.114790            0               0
# 4        0.475935     0.123572            0               1
# ...           ...          ...          ...             ...
# 1146     0.537470     0.116795            0               0
# 1147     0.516733     0.124190            0               0
# 1148     0.560632     0.129843            0               0
# 1149     0.485972     0.106690            1               1
# 1150     0.556192     0.088957            0               0
#
# [1151 rows x 20 columns]

# %%
df.isna().sum()
# Out:
# attribute0        0
# attribute1        0
# attribute2        0
# attribute3        0
# attribute4        0
# attribute5        0
# attribute6        0
# attribute7        0
# attribute8        0
# attribute9        0
# attribute10       0
# attribute11       0
# attribute12       0
# attribute13       0
# attribute14       0
# attribute15       0
# attribute16       0
# attribute17       0
# attribute18       0
# attributeClass    0
# dtype: int64

# %%
Features=df.drop('attributeClass', axis=1)
Label=df['attributeClass']

# %% [markdown]
# #PCA

# %%
# mean Centering the data  
Features_meaned = Features - np.mean(Features , axis = 0)
Features_meaned
# Out:
#       attribute0  attribute1  attribute2  attribute3  attribute4  attribute5  \
# 0       0.003475    0.081668  -16.428323  -14.909644  -13.140747  -13.297133
# 1       0.003475    0.081668  -14.428323  -12.909644  -13.140747  -14.297133
# 2       0.003475    0.081668   23.571677   23.090356   23.859253   21.702867
# 3       0.003475    0.081668   16.571677   16.090356   17.859253   17.702867
# 4       0.003475    0.081668    5.571677    7.090356    8.859253    8.702867
# ...          ...         ...         ...         ...         ...         ...
# 1146    0.003475    0.081668   -4.428323   -2.909644   -1.140747    0.702867
# 1147    0.003475    0.081668   10.571677   12.090356   13.859253   16.702867
# 1148    0.003475   -0.918332   10.571677   11.090356   12.859253   12.702867
# 1149    0.003475    0.081668    0.571677   -0.909644   -6.140747   -9.297133
# 1150    0.003475    0.081668  -31.428323  -29.909644  -28.140747  -25.297133
#
#       attribute6  attribute7  attribute8  attribute9  attribute10  \
# 0     -10.747176   -7.151173  -14.200918   -5.312018    -3.433690
# 1     -12.747176   -8.151173   -6.386738    0.711982    -5.379187
# 2      18.252824   11.848827   -8.265233    4.905921     3.982875
# 3      14.252824    9.848827  -23.629446   -4.642058     0.414291
# 4      10.252824    5.848827  -46.070420  -14.517303    -8.294229
# ...          ...         ...         ...         ...          ...
# 1146    2.252824    2.848827  -58.024909  -22.150540    -8.673465
# 1147   16.252824   15.848827   -0.899529    4.289656    -0.636922
# 1148   14.252824   11.848827  -33.634776   -9.121032    -6.941305
# 1149  -15.747176  -14.151173  -23.570935  -10.483065    -3.963691
# 1150  -21.747176  -16.151173    5.326891  -16.056169    -6.954062
#
#       attribute11  attribute12  attribute13  attribute14  attribute15  \
# 0       -1.064728    -0.542106    -0.205426    -0.081751    -0.033302
# 1       -1.602304    -0.556835    -0.208387    -0.081771    -0.033322
# 2        3.015793     0.833151     0.160962    -0.043857    -0.029481
# 3        1.242939     0.279523     0.060144    -0.078021    -0.035694
# 4       -1.836489    -0.560738    -0.212290    -0.085674    -0.037225
# ...           ...          ...          ...          ...          ...
# 1146    -1.833374    -0.560738    -0.212290    -0.085674    -0.037225
# 1147    -0.856941    -0.559186    -0.212290    -0.085674    -0.037225
# 1148    -1.698631    -0.549517    -0.212290    -0.085674    -0.037225
# 1149    -0.758919     0.002780     0.114570     0.153894     0.137359
# 1150    -1.789892    -0.539558    -0.203818    -0.085674    -0.037225
#
#       attribute16  attribute17  attribute18
# 0       -0.036309    -0.008406     0.663771
# 1       -0.002304     0.035983    -0.336229
# 2        0.007692     0.020117    -0.336229
# 3       -0.039928     0.006359    -0.336229
# 4       -0.047277     0.015141    -0.336229
# ...           ...          ...          ...
# 1146     0.014258     0.008364    -0.336229
# 1147    -0.006479     0.015759    -0.336229
# 1148     0.037420     0.021412    -0.336229
# 1149    -0.037240    -0.001741     0.663771
# 1150     0.032980    -0.019474    -0.336229
#
# [1151 rows x 19 columns]

# %%
# Calculate the co-variance matrix of the mean-centered data.
cov_matrix = np.cov(Features_meaned , rowvar = False)

# %%
#Calculating Eigenvalues and Eigenvectors of the covariance matrix
eigen_values , eigen_vectors = np.linalg.eigh(cov_matrix)

# %%
#sort the eigenvalues in descending order
sorted_index = np.argsort(eigen_values)[::-1]
 
sorted_eigenvalue = eigen_values[sorted_index]
#similarly sort the eigenvectors 
sorted_eigenvectors = eigen_vectors[:,sorted_index]
sorted_eigenvectors
# Out:
# array([[-3.50539918e-05,  9.38610767e-05, -5.24850446e-06,
#          2.05669557e-04,  4.77702422e-04, -8.61093051e-04,
#          4.32277043e-05, -8.53217300e-04,  9.99849865e-04,
#         -3.18441040e-03,  3.89185678e-04, -4.77408497e-03,
#          8.91710422e-03, -6.72197541e-03, -3.52632077e-03,
#          9.99624486e-01, -7.91895070e-03, -3.67071586e-03,
#          2.23993769e-02],
#        [-1.23389877e-04,  5.48810431e-04,  2.29278874e-04,
Features_reduced
# Out:
# array([[-1.97900675e+00, -3.52919831e+01, -5.21457008e-01, ...,
#          6.09757012e-01, -1.24873123e-01,  3.02617046e-01],
#        [-9.51735214e+00, -3.04148166e+01, -2.06904762e+00, ...,
#         -8.91214869e-03, -3.20440613e-01, -2.13707381e-01],
#        [ 3.00454102e+01,  4.20494476e+01, -6.14547757e+00, ...,
#          6.52087538e-01, -9.51015358e-01,  2.98544529e-02],
#        ...,
#        [ 4.55203400e+01,  7.81926614e+00,  7.92440613e-01, ...,
#          5.93043985e-01, -8.24462549e-02, -4.94025391e-02],
#        [ 1.40219245e+01, -2.61177523e+01,  2.06165012e+00, ...,
#         -1.37454578e+00,  1.25013442e-02,  1.73219079e-01],
#        [-3.07696423e+01, -5.66858817e+01,  1.48712011e+01, ...,
#          9.68444568e-02, -3.11347563e-02, -2.67810526e-01]])

# %%
PCA_df = pd.DataFrame(Features_reduced)
PCA_df
# Out:
#              0          1          2          3         4         5   \
# 0     -1.979007 -35.291983  -0.521457   0.463676  0.128485  0.058177
# 1     -9.517352 -30.414817  -2.069048  -2.074442  4.514808 -1.814393
# 2     30.045410  42.049448  -6.145478  -0.345946 -1.603065 -0.467848
# 3     39.335982  21.846116  -2.345317   0.820014 -2.505058  0.502037
# 4     51.970653  -8.012555   1.179980   2.473223  0.486310 -0.499335
# ...         ...        ...        ...        ...       ...       ...
# 1146  53.649503 -32.802768   2.646508   2.801775 -2.988378  0.956816
# 1147  16.651252  29.066447  -1.971683  11.499146  1.841278 -1.184401
# 1148  45.520340   7.819266   0.792441   5.764395  1.466454 -1.063125
# 1149  14.021924 -26.117752   2.061650 -19.064107  0.745310  1.615084
# 1150 -30.769642 -56.685882  14.871201   0.883400 -1.844197 -0.098698
#
#             6         7         8         9         10        11
# 0     0.370827  0.442070 -0.913994  0.609757 -0.124873  0.302617
# 1     1.912693  0.859605 -1.237429 -0.008912 -0.320441 -0.213707
# 2    -2.577975  1.105184  0.127648  0.652088 -0.951015  0.029854
# 3    -2.686971  1.211528  1.161932  0.543413 -0.440047 -0.048615
# 4    -2.537208 -0.255315 -0.978158  0.368900 -0.073267 -0.067000
# ...        ...       ...       ...       ...       ...       ...
# 1146 -0.771735  0.189820 -0.015092 -0.114611  0.027039 -0.122992
# 1147  0.071296  1.055250  0.868377 -0.474312  0.101925 -0.147540
# 1148 -0.131383 -0.061225 -0.533524  0.593044 -0.082446 -0.049403
# 1149  0.741135  1.756153  0.675071 -1.374546  0.012501  0.173219
# 1150 -0.336926 -0.626488  0.026212  0.096844 -0.031135 -0.267811
#
# [1151 rows x 12 columns]

# %%
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics

# %% [markdown]
# #Split the dataset to Test/Train

# %%
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(PCA_df, Label, test_size=0.3, random_state=1)

# %% [markdown]
# #Decision Tree

# %%
# Import Decision Tree Classifier
from sklearn.tree import DecisionTreeClassifier
# Create Decision Tree classifer object
clf = DecisionTreeClassifier()

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred_train = clf.predict(X_train)

# %%
print("Decision Tree Model Accuracy with training data (in %):",metrics.accuracy_score(y_train, y_pred_train)*100)
# Out:
# Decision Tree Model Accuracy with training data (in %): 100.0

# %%
# Create Decision Tree classifer object
clf = DecisionTreeClassifier(criterion="entropy", max_depth=8)

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

# %%
DT_Results = ['PCA', 'DT']
# Model Accuracy, how often is the classifier correct?
DT_Results.append(metrics.accuracy_score(y_test, y_pred)*100)
DT_Results.append(metrics.precision_score(y_test,y_pred,average='micro')*100)
DT_Results.append(metrics.f1_score(y_test,y_pred,average='micro')*100)
DT_Results.append(metrics.recall_score(y_test,y_pred,average='micro')*100)

print("Decision Tree model accuracy (in %):", metrics.accuracy_score(y_test, y_pred)*100)
print("Decision Tree model Precision Score (in %):", metrics.precision_score(y_test,y_pred,average='micro')*100)
print("Decision Tree model f1 Score (in %):", metrics.f1_score(y_test,y_pred,average='micro')*100)
print("Decision Tree model Recall Score (in %):", metrics.recall_score(y_test,y_pred,average='micro')*100)
# Out:
# Decision Tree model accuracy (in %): 69.65317919075144
# Decision Tree model Precision Score (in %): 69.65317919075144
# Decision Tree model f1 Score (in %): 69.65317919075144
# Decision Tree model Recall Score (in %): 69.65317919075144

# %%
db_pca=pd.DataFrame(columns=['Method','Classifier','Accuracy','Precision_Score','F1-Score','Recall_Score'])

# %%
db_pca.loc[len(db_pca)] = DT_Results
db_pca
# Out:
#   Method Classifier   Accuracy  Precision_Score   F1-Score  Recall_Score
# 0    PCA         DT  69.653179        69.653179  69.653179     69.653179

# %% [markdown]
# #Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB() 
gnb.fit(X_train, y_train) 

y_pred_train = gnb.predict(X_train)

print('Gaussian Naive Bayes Training-set accuracy(in %):', metrics.accuracy_score(y_train, y_pred_train)*100)
# Out:
# Gaussian Naive Bayes Training-set accuracy(in %): 65.59006211180125

# %%
# making predictions on the testing set 
y_pred = gnb.predict(X_test)

NB_Results = ['PCA', 'NB']
# Model Accuracy, how often is the classifier correct?
NB_Results.append(metrics.accuracy_score(y_test, y_pred)*100)
NB_Results.append(metrics.precision_score(y_test,y_pred,average='micro')*100)
NB_Results.append(metrics.f1_score(y_test,y_pred,average='micro')*100)
NB_Results.append(metrics.recall_score(y_test,y_pred,average='micro')*100)

print("Naive Bayes model accuracy (in %):", metrics.accuracy_score(y_test, y_pred)*100)
print("Naive Bayes model Precision Score (in %):", metrics.precision_score(y_test,y_pred,average='micro')*100)
print("Naive Bayes model f1 Score (in %):", metrics.f1_score(y_test,y_pred,average='micro')*100)
print("Naive Bayes model Recall Score (in %):", metrics.recall_score(y_test,y_pred,average='micro')*100)
# Out:
# Naive Bayes model accuracy (in %): 68.20809248554913
# Naive Bayes model Precision Score (in %): 68.20809248554913
# Naive Bayes model f1 Score (in %): 68.20809248554913
# Naive Bayes model Recall Score (in %): 68.20809248554913

# %%
db_pca.loc[len(db_pca)] = NB_Results
db_pca
# Out:
#   Method Classifier   Accuracy  Precision_Score   F1-Score  Recall_Score
# 0    PCA         DT  69.653179        69.653179  69.653179     69.653179
# 1    PCA         NB  68.208092        68.208092  68.208092     68.208092

# %% [markdown]
# #Random Forest

# %%
# importing random forest classifier from assemble module
from sklearn.ensemble import RandomForestClassifier

# %%
# creating a RF classifier
rfclf = RandomForestClassifier(n_estimators = 100) 
 
# Training the model on the training dataset
rfclf.fit(X_train, y_train)
y_pred_train = rfclf.predict(X_train)

print('Training-set accuracy(in %):', metrics.accuracy_score(y_train, y_pred_train)*100)
# Out:
# Training-set accuracy(in %): 100.0

# %%
# performing predictions on the test dataset
y_pred = rfclf.predict(X_test)

RF_Results = ['PCA', 'RF']
# Model Accuracy, how often is the classifier correct?
RF_Results.append(metrics.accuracy_score(y_test, y_pred)*100)
RF_Results.append(metrics.precision_score(y_test,y_pred,average='micro')*100)
RF_Results.append(metrics.f1_score(y_test,y_pred,average='micro')*100)
RF_Results.append(metrics.recall_score(y_test,y_pred,average='micro')*100)

print("Random Forest model accuracy (in %):", metrics.accuracy_score(y_test, y_pred)*100)
print("Random Forest model Precision Score (in %):", metrics.precision_score(y_test,y_pred,average='micro')*100)
print("Random Forest model f1 Score (in %):", metrics.f1_score(y_test,y_pred,average='micro')*100)
print("Random Forest model Recall Score (in %):", metrics.recall_score(y_test,y_pred,average='micro')*100)
# Out:
# Random Forest model accuracy (in %): 70.8092485549133
# Random Forest model Precision Score (in %): 70.8092485549133
# Random Forest model f1 Score (in %): 70.8092485549133
# Random Forest model Recall Score (in %): 70.8092485549133

# %%
db_pca.loc[len(db_pca)] = RF_Results
db_pca
# Out:
#   Method Classifier   Accuracy  Precision_Score   F1-Score  Recall_Score
# 0    PCA         DT  69.653179        69.653179  69.653179     69.653179
# 1    PCA         NB  68.208092        68.208092  68.208092     68.208092
# 2    PCA         RF  70.809249        70.809249  70.809249     70.809249

# %% [markdown]
# #SVM

# %%
#Import svm model
from sklearn import svm

#Create a svm Classifier
svmclf = svm.SVC(kernel='linear') # Linear Kernel

#Train the model using the training sets
svmclf.fit(X_train, y_train)

y_pred_train = svmclf.predict(X_train)

print('Training-set accuracy(in %):', metrics.accuracy_score(y_train, y_pred_train)*100)
# Out:
# Training-set accuracy(in %): 75.90062111801242

# %%
#Predict the response for test dataset
y_pred = svmclf.predict(X_test)

SVM_Results = ['PCA', 'SVM']
# Model Accuracy, how often is the classifier correct?
SVM_Results.append(metrics.accuracy_score(y_test, y_pred)*100)
SVM_Results.append(metrics.precision_score(y_test,y_pred,average='micro')*100)
SVM_Results.append(metrics.f1_score(y_test,y_pred,average='micro')*100)
SVM_Results.append(metrics.recall_score(y_test,y_pred,average='micro')*100)

print("SVM model accuracy (in %):", metrics.accuracy_score(y_test, y_pred)*100)
print("SVM model Precision Score (in %):", metrics.precision_score(y_test,y_pred,average='micro')*100)
print("SVM model f1 Score (in %):", metrics.f1_score(y_test,y_pred,average='micro')*100)
print("SVM model Recall Score (in %):", metrics.recall_score(y_test,y_pred,average='micro')*100)
# Out:
# SVM model accuracy (in %): 72.54335260115607
# SVM model Precision Score (in %): 72.54335260115607
# SVM model f1 Score (in %): 72.54335260115607
# SVM model Recall Score (in %): 72.54335260115607

# %% [markdown]
# # Results

# %%
db_pca.loc[len(db_pca)] = SVM_Results
db_pca
# Out:
#   Method Classifier   Accuracy  Precision_Score   F1-Score  Recall_Score
# 0    PCA         DT  69.653179        69.653179  69.653179     69.653179
# 1    PCA         NB  68.208092        68.208092  68.208092     68.208092
# 2    PCA         RF  70.809249        70.809249  70.809249     70.809249
# 3    PCA        SVM  72.543353        72.543353  72.543353     72.543353

# %% [markdown]
# # Visualization of Results

# %%
ax=db_pca.plot(x='Classifier',
        kind='bar',
        stacked=False,
        figsize=(8,5),
        ylim=(50,80),
        legend = 1,
        title='Classifiers with LDA',
        ylabel='Measures')
